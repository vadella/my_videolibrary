# %%
from pathlib import Path
import datetime
import re
from my_videolibrary.mkv_enzyme import MkvFile

# %%
DATA_DIR = Path("//OnzeNas/FILM_Eigen/")

# %%
FILENAME_PATTERN = re.compile("^(?P<title>.+?) \((?P<year>\d{4})\).mkv$")

# %%
def parse_track(track, movie_id):
    d = track.__dict__
    d["movie_id"] = movie_id
    if "duration" in d:
        d["duration"] = str(d["duration"]).split(".")[0]
    return {key: value for key, value in d.items() if value is not None}


def parse_tracks(tracks, movie_id):
    return [parse_track(track, movie_id) for track in tracks]


def parse_info(movie_file: Path, movie_info: MkvFile):
    movie_name = movie_file.name
    movie_id = hash(f"{movie_name} + {str(movie_info.info)}")
    match = FILENAME_PATTERN.match(movie_name)
    if match:
        name, year = FILENAME_PATTERN.match(movie_name).groups()
    else:
        print(f"{movie_name} does not match the pattern")
        name, year = movie_name, None
    info = dict(name=name, year=year, location=str(movie_file))
    info.update(parse_track(movie_info.info, movie_id))

    video_info = parse_tracks(movie_info.video_tracks, movie_id)
    if len(video_info) != 1:
        raise ValueError(f"more than 1 videotrack for {movie_name}")
    info.update(video_info[0])
        
    audio_info = parse_tracks(movie_info.audio_tracks, movie_id)
    sub_info = parse_tracks(movie_info.subtitle_tracks, movie_id)
    return dict(
        info=info,
        audio_info=audio_info,
        sub_info=sub_info,
    )

# %%
import pymongo
from pymongo import MongoClient

# %%
def insert_non_existing(collection: pymongo.collection.Collection, document):
    if collection.find_one(document):
        return None
    return collection.insert_one(document).inserted_id

# %%
DATA_DIR = Path("//OnzeNas/FILM_Eigen/")
# DATA_DIR = DATA_DIR / "Madagascar Collection"
movies = list(DATA_DIR.glob("**/*.mkv"))
movies_info = {
    file: MkvFile(file=file)
    for file in movies
}

# %%
with MongoClient() as client:
    db = client.my_videos
    collection_movies = db.movies
    collection_videos = db.video_tracks
    collection_audio = db.audio_tracks
    collection_sub = db.subtitle_tracks
    for movie_name, movie_info in movies_info.items():
        print(movie_name.name)
        info = parse_info(movie_name, movie_info)
        insert_non_existing(collection_movies, info["info"])
        for info_track in info["audio_info"]:
            insert_non_existing(collection_audio, info_track)
        for info_track in info["sub_info"]:
            insert_non_existing(collection_sub, info_track)
# Out:
# West Side Story (1961).mkv
# 3 -10 to Yuma (2007).mkv
# Ben-Hur (1959).mkv
# The Lord of the Rings - The Two Towers (2002).mkv
# The Lord of the Rings - The Fellowship of the Ring (2001).mkv
# The Lord of the Rings - The Return of the King (2003).mkv
# C'est arrivé pres de chez vous (1992).mkv
# Fight Club (1999).mkv
# Walk the Line (2005).mkv
# There Will Be Blood (2007).mkv
# Taxi Driver (1976).mkv
# The Hidden Fortress (1958).mkv
# Cars (2006).mkv
# The Shining (1980).mkv
# Waltz with Bashir (2008).mkv
# Eyes Wide Shut (1999).mkv
# Dog Day Afternoon (1975).mkv
# Seven Samurai (1954).mkv
# American Gangster (2007).mkv
# The Great Gatsby (2013).mkv
# Full Metal Jacket (1987).mkv
# Steve + Sky (2004).mkv
# Spring, Summer, Fall, Winter... and Spring (2003).mkv
# Flags of Our Fathers (2006).mkv
# Se7en (1995).mkv
# Ratatouille (2007).mkv
# House of Flying Daggers (2004).mkv
# Romeo + Juliet (1996).mkv
# Apocalypse Now (1979).mkv
# Sanjuro (1962).mkv
# The Wolf of Wall Street (2013).mkv
# Carlito's Way (1993).mkv
# Yojimbo (1961).mkv
# Scarface (1983).mkv
# Ice Age 3 - Dawn of the Dinosaurs (2009).mkv
# Ice Age (2002).mkv
# Ice Age 4 - Continental Drift (2012).mkv
# Ice Age 2 - The Meltdown (2006).mkv
# The Hobbit - An Unexpected Journey (2012).mkv
# The Hobbit - The Battle of the Five Armies (2014).mkv
# The Hobbit - The Desolation of Smaug (2013).mkv
# Inside Out (2015).mkv
# Finding Nemo (2003).mkv
# Cleopatra (1963).mkv
# A Fistful of Dollars (1964).mkv
# For a Few Dollars More (1965).mkv
# The Good, the Bad and the Ugly (1966).mkv
# Happy Feet (2006).mkv
# Nosferatu (1922).mkv
# V for Vendetta (2005).mkv
# The Matrix (1999).mkv
# The Matrix Revolutions (2003).mkv
# The Matrix Reloaded (2003).mkv
# Monty Python's The Meaning of Life (1983).mkv
# Monty Python's Life of Brian (1979).mkv
# Monty Python Live at the Hollywood Bowl (1982).mkv
# Meeting People Is Easy (1998).mkv
# Paths of Glory (1957).mkv
# Lolita (1962).mkv
# Madagascar (2005).mkv
# Madagascar 3 - Europe's Most Wanted (2012).mkv
# Madagascar 2 - Escape 2 Africa (2008).mkv
# Throne of Blood (1957).mkv
# Kommil Foo - Breken (2012).mkv
# Finding Dory (2016).mkv
# Crouching Tiger, Hidden Dragon (2000).mkv
# Magnolia (1999).mkv
# The Silence of the Lambs (1991).mkv
# Dirty Dancing - Havana Nights (2004).mkv
# The Great Escape (1963).mkv
# Moulin Rouge! (2001).mkv
# Batman Begins (2005).mkv
# The Dark Knight (2008).mkv
# The Dark Knight Rises (2012).mkv
# Queen - Rock Montreal (1981).mkv
# WALL·E (2008).mkv
# Sin City 2 - A Dame to Kill For (2014).mkv
# Inglourious Basterds (2009).mkv
# Monsters, Inc. (2001).mkv
# Django Unchained (2012).mkv
# Walking with Dinosaurs 3D (2013).mkv
# A Clockwork Orange (1971).mkv
# The Broken Circle Breakdown (2012).mkv
# Inception (2010).mkv
# Kill Bill - Vol. 2 (2004).mkv
# Kill Bill - Vol. 1 (2003).mkv
# 300 (2006).mkv
# The Jungle Book (1967).mkv
# Shakespeare in Love (1998).mkv
# Mulholland Drive (2001).mkv
# 9 (2009).mkv
# 2001 - A Space Odyssey (1968).mkv
# Once Upon a Time in America (1984).mkv
# Barry Lyndon (1975).mkv
# Dr. Strangelove or - How I Learned to Stop Worrying and Love the Bomb (1964).mkv
# Blade Runner (1982).mkv
# Big Fish (2003).mkv
# Star Trek Into Darkness (2013).mkv
# Metropolis (1927).mkv
# The Piano (1993).mkv
# Casino (1995).mkv
# Radiohead - TKOL -  Live From the Basement (2011).mkv
# Le Huitième jour (1996).mkv
# Any Way the Wind Blows (2003).mkv
# Duck, You Sucker (1971).mkv
# Drive (2011).mkv
# Dagen zonder lief (2007).mkv
# Elephant (2003).mkv
# Black Swan (2010).mkv
# The Godfather - Part II (1974).mkv
# The Godfather (1972).mkv
# The Godfather - Part III (1990).mkv
# Skyfall (2012).mkv
# Quantum of Solace (2008).mkv
# Casino Royale (2006).mkv

# %%
def _summarize_tracks(tracks):
    return dict(amount=len(tracks), summary="\n".join(map(str, tracks)))


class Movie:
    def __init__(self, properties):
        self._properties = properties.copy()
        self._audiotracks = [
            AudioTrack(track) for track in properties.pop("audio_tracks", [])
        ]
        self._subtitle_tracks = [
            SubtitleTrack(track)
            for track in properties.pop("subtitle_tracks", [])
        ]

    def __getitem__(self, key):
        return self._properties[key]

    def get(self, key, default=None):
        self._properties.get(key, default)

    @property
    def summary_general(self):
        items = (
            "name",
            "year",
            "duration",
            "display_width",
            "display_height",
            "codec_id",
            "location",
        )
        return {item: self[item] for item in items}

    @property
    def summary_audio(self):
        return _summarize_tracks(self._audiotracks)

    @property
    def summary_subtitle(self):
        return _summarize_tracks(self._subtitle_tracks)

    @property
    def summary_complete(self):
        return dict(
            **self.summary_general,
            **{
                f"audio_{key}": value
                for key, value in self.summary_audio.items()
            },
            **{
                f"sub_{key}": value for key, value in self.summary_subtitle.items()
            },
        )

    def __repr__(self):
        properties = dict(
            **self._properties,
            audiotracks=self._audiotracks,
            subtitletracks=self._subtitle_tracks,
        )
        return f"{type(self).__name__}({properties})"

# %%
class Track:
    _class_fields: tuple
    _suffixes: dict = {}

    def __init__(self, properties):
        self._properties = properties

    @property
    def _fields(self):
        return [
            f"{self._properties.get(field, '')}{type(self)._suffixes.get(field,'')}"
            for field in self._class_fields
        ]

    def __str__(self):
        return (
            ";".join(self._fields) + (":default" if self._properties["default"] else "")
        )

    def __repr__(self):
        return f"{type(self).__name__}(properties={self._properties.copy()})"


class AudioTrack(Track):
    _class_fields = ("name", "language", "number", "codec_id", "channels")


class SubtitleTrack(Track):
    _class_fields = ("language", "number")

# %%
lookup_query = [
            {
                "$lookup": {
                    "from": "audio_tracks",
                    "localField": "movie_id",
                    "foreignField": "movie_id",
                    "as": "audio_tracks",
                }
            },
            {
                "$lookup": {
                    "from": "subtitle_tracks",
                    "localField": "movie_id",
                    "foreignField": "movie_id",
                    "as": "subtitle_tracks",
                }
            },
        ]

# %%
with MongoClient() as client:
    db = client.my_videos
    collection_movies = db.movies
    query_results = list(
        Movie(movie) for movie in collection_movies.aggregate(lookup_query)
    )


query_results[:5]
# Out:
# [Movie({'_id': ObjectId('5bda0e07231d8f1b7c667e49'), 'name': 'West Side Story', 'year': '1961', 'location': '\\\\OnzeNas\\FILM_Eigen\\West Side Story (1961)\\West Side Story (1961).mkv', 'duration': '2:52:55', 'muxing_app': 'Lavf55.12.0', 'writing_app': 'HandBrake 0.10.1 2015030800', 'movie_id': -2078791735790941593, 'type': 1, 'number': 1, 'language': 'und', 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'V_MPEG4/ISO/AVC', 'width': 1920, 'height': 880, 'interlaced': False, 'crop': {}, 'display_width': 1928, 'display_height': 880, 'display_unit': 3, 'audio_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e4a'), 'type': 2, 'number': 2, 'name': 'Surround', 'language': 'eng', 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'A_DTS', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': -2078791735790941593}, {'_id': ObjectId('5bda0e07231d8f1b7c667e4b'), 'type': 2, 'number': 3, 'name': 'Stereo', 'language': 'eng', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'A_AAC', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': -2078791735790941593}], 'subtitle_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e4c'), 'type': 17, 'number': 4, 'language': 'eng', 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': -2078791735790941593}, {'_id': ObjectId('5bda0e07231d8f1b7c667e4d'), 'type': 17, 'number': 5, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': -2078791735790941593}], 'audiotracks': [AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e4a'), 'type': 2, 'number': 2, 'name': 'Surround', 'language': 'eng', 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'A_DTS', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': -2078791735790941593}), AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e4b'), 'type': 2, 'number': 3, 'name': 'Stereo', 'language': 'eng', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'A_AAC', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': -2078791735790941593})], 'subtitletracks': [SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e4c'), 'type': 17, 'number': 4, 'language': 'eng', 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': -2078791735790941593}), SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e4d'), 'type': 17, 'number': 5, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': -2078791735790941593})]}),
#  Movie({'_id': ObjectId('5bda0e07231d8f1b7c667e4e'), 'name': '3 -10 to Yuma', 'year': '2007', 'location': '\\\\OnzeNas\\FILM_Eigen\\3 -10 to Yuma (2007)\\3 -10 to Yuma (2007).mkv', 'duration': '1:57:21', 'muxing_app': 'libmkv 0.6.5', 'writing_app': 'HandBrake 0.9.9', 'movie_id': 2739465870948201239, 'type': 1, 'number': 1, 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'V_MPEG4/ISO/AVC', 'width': 720, 'height': 432, 'interlaced': False, 'crop': {}, 'display_width': 1033, 'display_height': 432, 'audio_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e4f'), 'type': 2, 'number': 2, 'language': 'eng', 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'A_DTS', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': 2739465870948201239}, {'_id': ObjectId('5bda0e07231d8f1b7c667e50'), 'type': 2, 'number': 3, 'language': 'eng', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'A_AC3', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': 2739465870948201239}], 'subtitle_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e51'), 'type': 17, 'number': 4, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_VOBSUB', 'movie_id': 2739465870948201239}], 'audiotracks': [AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e4f'), 'type': 2, 'number': 2, 'language': 'eng', 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'A_DTS', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': 2739465870948201239}), AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e50'), 'type': 2, 'number': 3, 'language': 'eng', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'A_AC3', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': 2739465870948201239})], 'subtitletracks': [SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e51'), 'type': 17, 'number': 4, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_VOBSUB', 'movie_id': 2739465870948201239})]}),
#  Movie({'_id': ObjectId('5bda0e07231d8f1b7c667e52'), 'name': 'Ben-Hur', 'year': '1959', 'location': '\\\\OnzeNas\\FILM_Eigen\\Ben-Hur (1959)\\Ben-Hur (1959).mkv', 'title': 'Ben-Hur (1959)', 'duration': '3:33:21', 'date_utc': datetime.datetime(2016, 12, 12, 20, 47, 8), 'muxing_app': 'libebml v1.3.4 + libmatroska v1.4.5', 'writing_app': "mkvmerge v9.6.0 ('Slave To Your Mind') 64bit", 'movie_id': -8064704386564529301, 'type': 1, 'number': 1, 'language': 'und', 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'V_MPEG4/ISO/AVC', 'width': 720, 'height': 376, 'interlaced': False, 'crop': {}, 'display_width': 1026, 'display_height': 376, 'audio_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e53'), 'type': 2, 'number': 2, 'name': 'En TrueHD', 'enabled': True, 'default': True, 'forced': False, 'lacing': True, 'codec_id': 'A_AC3', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': -8064704386564529301}, {'_id': ObjectId('5bda0e07231d8f1b7c667e54'), 'type': 2, 'number': 3, 'name': 'EN Stereo', 'enabled': True, 'default': False, 'forced': False, 'lacing': True, 'codec_id': 'A_AAC', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': -8064704386564529301}], 'subtitle_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e55'), 'type': 17, 'number': 4, 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'S_VOBSUB', 'movie_id': -8064704386564529301}, {'_id': ObjectId('5bda0e07231d8f1b7c667e56'), 'type': 17, 'number': 5, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_VOBSUB', 'movie_id': -8064704386564529301}], 'audiotracks': [AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e53'), 'type': 2, 'number': 2, 'name': 'En TrueHD', 'enabled': True, 'default': True, 'forced': False, 'lacing': True, 'codec_id': 'A_AC3', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': -8064704386564529301}), AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e54'), 'type': 2, 'number': 3, 'name': 'EN Stereo', 'enabled': True, 'default': False, 'forced': False, 'lacing': True, 'codec_id': 'A_AAC', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': -8064704386564529301})], 'subtitletracks': [SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e55'), 'type': 17, 'number': 4, 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'S_VOBSUB', 'movie_id': -8064704386564529301}), SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e56'), 'type': 17, 'number': 5, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_VOBSUB', 'movie_id': -8064704386564529301})]}),
#  Movie({'_id': ObjectId('5bda0e07231d8f1b7c667e57'), 'name': 'The Lord of the Rings - The Two Towers', 'year': '2002', 'location': '\\\\OnzeNas\\FILM_Eigen\\The Lord of the Rings Collection\\The Lord of the Rings - The Two Towers (2002)\\The Lord of the Rings - The Two Towers (2002).mkv', 'duration': '3:55:25', 'date_utc': datetime.datetime(2013, 12, 2, 12, 59, 6), 'muxing_app': 'libebml v1.3.0 + libmatroska v1.4.1', 'writing_app': "mkvmerge v6.5.0 ('Isn't she lovely') built on Oct 20 2013 12:50:05", 'movie_id': 4882939453205439315, 'type': 1, 'number': 1, 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'V_MPEG4/ISO/AVC', 'width': 1920, 'height': 800, 'interlaced': False, 'crop': {}, 'display_width': 1912, 'display_height': 800, 'audio_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e58'), 'type': 2, 'number': 2, 'enabled': True, 'default': True, 'forced': False, 'lacing': True, 'codec_id': 'A_DTS', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': 4882939453205439315}, {'_id': ObjectId('5bda0e07231d8f1b7c667e59'), 'type': 2, 'number': 3, 'enabled': True, 'default': False, 'forced': False, 'lacing': True, 'codec_id': 'A_AC3', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': 4882939453205439315}], 'subtitle_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e5a'), 'type': 17, 'number': 4, 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 4882939453205439315}, {'_id': ObjectId('5bda0e07231d8f1b7c667e5b'), 'type': 17, 'number': 5, 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 4882939453205439315}, {'_id': ObjectId('5bda0e07231d8f1b7c667e5c'), 'type': 17, 'number': 6, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 4882939453205439315}], 'audiotracks': [AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e58'), 'type': 2, 'number': 2, 'enabled': True, 'default': True, 'forced': False, 'lacing': True, 'codec_id': 'A_DTS', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': 4882939453205439315}), AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e59'), 'type': 2, 'number': 3, 'enabled': True, 'default': False, 'forced': False, 'lacing': True, 'codec_id': 'A_AC3', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': 4882939453205439315})], 'subtitletracks': [SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e5a'), 'type': 17, 'number': 4, 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 4882939453205439315}), SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e5b'), 'type': 17, 'number': 5, 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 4882939453205439315}), SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e5c'), 'type': 17, 'number': 6, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 4882939453205439315})]}),
#  Movie({'_id': ObjectId('5bda0e07231d8f1b7c667e5d'), 'name': 'The Lord of the Rings - The Fellowship of the Ring', 'year': '2001', 'location': '\\\\OnzeNas\\FILM_Eigen\\The Lord of the Rings Collection\\The Lord of the Rings - The Fellowship of the Ring (2001)\\The Lord of the Rings - The Fellowship of the Ring (2001).mkv', 'duration': '3:48:15', 'date_utc': datetime.datetime(2013, 12, 1, 22, 13, 41), 'muxing_app': 'libebml v1.3.0 + libmatroska v1.4.1', 'writing_app': "mkvmerge v6.5.0 ('Isn't she lovely') built on Oct 20 2013 12:50:05", 'movie_id': 3282301544551894014, 'type': 1, 'number': 1, 'enabled': True, 'default': True, 'forced': False, 'lacing': False, 'codec_id': 'V_MPEG4/ISO/AVC', 'width': 1920, 'height': 800, 'interlaced': False, 'crop': {}, 'display_width': 1920, 'display_height': 800, 'audio_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e5e'), 'type': 2, 'number': 2, 'enabled': True, 'default': True, 'forced': False, 'lacing': True, 'codec_id': 'A_DTS', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': 3282301544551894014}, {'_id': ObjectId('5bda0e07231d8f1b7c667e5f'), 'type': 2, 'number': 3, 'enabled': True, 'default': False, 'forced': False, 'lacing': True, 'codec_id': 'A_AC3', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': 3282301544551894014}], 'subtitle_tracks': [{'_id': ObjectId('5bda0e07231d8f1b7c667e60'), 'type': 17, 'number': 4, 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 3282301544551894014}, {'_id': ObjectId('5bda0e07231d8f1b7c667e61'), 'type': 17, 'number': 5, 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 3282301544551894014}, {'_id': ObjectId('5bda0e07231d8f1b7c667e62'), 'type': 17, 'number': 6, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 3282301544551894014}], 'audiotracks': [AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e5e'), 'type': 2, 'number': 2, 'enabled': True, 'default': True, 'forced': False, 'lacing': True, 'codec_id': 'A_DTS', 'sampling_frequency': 48000.0, 'channels': 6, 'movie_id': 3282301544551894014}), AudioTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e5f'), 'type': 2, 'number': 3, 'enabled': True, 'default': False, 'forced': False, 'lacing': True, 'codec_id': 'A_AC3', 'sampling_frequency': 48000.0, 'channels': 2, 'movie_id': 3282301544551894014})], 'subtitletracks': [SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e60'), 'type': 17, 'number': 4, 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 3282301544551894014}), SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e61'), 'type': 17, 'number': 5, 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 3282301544551894014}), SubtitleTrack(properties={'_id': ObjectId('5bda0e07231d8f1b7c667e62'), 'type': 17, 'number': 6, 'language': 'dut', 'enabled': True, 'default': False, 'forced': False, 'lacing': False, 'codec_id': 'S_HDMV/PGS', 'movie_id': 3282301544551894014})]})]

# %%
q = query_results[0]

# %%
q.summary_complete
# Out:
# {'name': 'West Side Story',
#  'year': '1961',
#  'duration': '2:52:55',
#  'display_width': 1928,
#  'display_height': 880,
#  'codec_id': 'V_MPEG4/ISO/AVC',
#  'location': '\\\\OnzeNas\\FILM_Eigen\\West Side Story (1961)\\West Side Story (1961).mkv',
#  'audio_amount': 2,
#  'audio_summary': 'Surround;eng;2;A_DTS;6:default\nStereo;eng;3;A_AAC;2',
#  'sub_amount': 2,
#  'sub_summary': 'eng;4:default\ndut;5'}
